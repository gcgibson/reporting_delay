# %%
PROVINCE = "50"
import matplotlib.pyplot as plt
count = 0
total_cases = []
with open("total_data.csv") as f:
    for line in f.readlines():
        #print (line)
        if count ==0:
            count +=1
        else:
            line_split = line.split(",")
            
            if line_split[2] == PROVINCE and len(line_split) >=3:
                total_cases.append(float(line_split[3]))
                
print (len(total_cases))
proc_training_data_base = total_cases[(26*20):(len(total_cases) - 26*4)]
plt.plot(proc_training_data_base)
plt.show()
# Out:
# 1804

# %%
from contextlib import contextmanager
import sys, os

@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:  
            yield
        finally:
            sys.stdout = old_stdout
            
            
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

plt.rcParams['lines.linewidth']=1
plt.rcParams['axes.facecolor']='w'

n_t_d = []
with open("province-biweek_with_delays.csv") as f:
    i = 0
    for line in f.readlines():
        if i > 0:
            n_t_d.append(line.replace("\n","").split(','))
        i+=1

n_t_d_1 = []

for elm in n_t_d:
    if elm[2] == PROVINCE:
        n_t_d_1.append(elm)


index_to_dates = {}
dates_to_index = {}
count = 0
for i in ["2014","2015","2016"]:
    for j in range(1,27):
        index_to_dates[count] = str(i)+str(j)
        dates_to_index[str(i)+str(j)] = count
        count +=1
        
reporting_matrix = np.zeros((26*3,26*3))

for elm in n_t_d_1:
    try:
        sick_date = elm[0]+elm[1]
        report_date = elm[-2] + elm[-1]
        cases = elm[3]
        reporting_matrix_row = dates_to_index[sick_date] 
        reporting_matrix_col =  dates_to_index[report_date] 
        reporting_matrix[reporting_matrix_row,reporting_matrix_col] = int(cases)
    except:
        pass
np.set_printoptions(suppress=True)    #np.set_printoptions(threshold=np.nan)


D=10
n_t_d = np.zeros((len(reporting_matrix),D))

for i in range(len(reporting_matrix)):
    for j in range(i,i+D):
        try:
            n_t_d[i,j-i] = reporting_matrix[i][j]
        except:
            pass
n_t_d = n_t_d 

from matplotlib.pyplot import cm


def sim_data(x,y,z):
    return n_t_d[:y]

np.savetxt("foo.csv", n_t_d, delimiter=",",fmt='%f')



pos=[]
biweek_x_label = []
for year in ["2014","2015","2016"]:
    for j in np.arange(1,27,13):
        if j <= 9:
               biweek_x_label.append(year + "0"+ str(j))

        else:
               biweek_x_label.append(year +  str(j))
        if year == "2014":
               pos.append(j)
        elif year == "2015":
               pos.append(j+26)
        elif year == "2016":
               pos.append(j+26*2)

p_hat_sim = []

for i in range(len(n_t_d)):
        #print (sum(sim_n_t_d[i]/np.sum(sim_n_t_d[i])))
        p_hat_sim.append(n_t_d[i]/np.sum(n_t_d[i]))


plt.plot(p_hat_sim)
plt.xticks(pos, biweek_x_label, rotation='vertical')
plt.xlabel("\nDate")
plt.title("DHF Incidence in Chiang Mai")
plt.ylabel("Incidence")
plt.show()

plt.figure(figsize=(8,8))
plt.ylabel("Bi-week")
plt.xlabel("d")
plt.imshow(p_hat_sim,aspect='auto',cmap=cm.Blues)
plt.legend()
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.interpolate import interp1d
import statsmodels.api as sm

# introduce some floats in our x-values
x = list(range(3, 33)) + [3.2, 6.2]
y = [1,2,1,2,1,1,3,4,5,4,5,6,5,6,7,8,9,10,11,11,12,11,11,10,12,11,11,10,9,8,2,13]

# lowess will return our "smoothed" data with a y value for at every x-value
lowess = sm.nonparametric.lowess(y, x, frac=.3)

# unpack the lowess smoothed points to their values
lowess_x = list(zip(*lowess))[0]
lowess_y = list(zip(*lowess))[1]

# run scipy's interpolation. There is also extrapolation I believe
f = interp1d(lowess_x, lowess_y, bounds_error=False)

xnew = [i/10. for i in range(400)]

# this this generate y values for our xvalues by our interpolator
# it will MISS values outsite of the x window (less than 3, greater than 33)
# There might be a better approach, but you can run a for loop
#and if the value is out of the range, use f(min(lowess_x)) or f(max(lowess_x))
ynew = f(xnew)


plt.plot(x, y, 'o')
plt.plot(lowess_x, lowess_y, '*')
plt.plot(xnew, ynew, '-')
plt.show()

# %%
from scipy.special import expit
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
variance_level_results = []
import sys
from pydlm import dlm, trend, seasonality, dynamic, autoReg, longSeason
from sklearn.metrics import mean_squared_error
from pyramid.arima import ARIMA
import GPy
import os
LO=D
rmse_vec_cv = []
#with suppress_stdout():
rmse_vec = []
sim_data_var = []
N_SIM = 100
sim_results_pi = []
sim_results_mse = []
for sim_num in np.arange(30,len(n_t_d)):
            sim_n_t_d = sim_data(D,sim_num,False)
            train = sim_n_t_d
            


            train = np.array(train)
            train_n_t_d = train.reshape((-1,D))
            ts = train_n_t_d.sum(axis=1)
            data_to_be_scaled_down  = train_n_t_d[len(ts)-D:]




            delayed_data = []
            count = D
            for i in range(len(data_to_be_scaled_down)):
                tmp = data_to_be_scaled_down[i][:count].tolist()
                while len(tmp) <D:
                    tmp.append(0)
                delayed_data.append(tmp)
                count -=1 


            training_data = np.append(train_n_t_d[:len(ts)-D],delayed_data,axis=0)

            k = np.array(train_n_t_d).shape[1 ]
            alphas = np.ones(k)

            for i in range(len(ts)-D):
                alphas += train_n_t_d[i]

            
           
            #######
            # MODEL 1: Delay
            ########
            delay_model_samples = []
            for s_ in range(N_SIM):
                model_1_delay = []
                count = D
                p_vec_noise = np.random.dirichlet(.01*alphas)
                for i in range(len(delayed_data)):
                    delay_forecast = np.sum(delayed_data[i])/np.sum(p_vec_noise[:count])
                    model_1_delay.append(np.round(delay_forecast,2))
                    count -= 1
                delay_model_samples.append(model_1_delay)
            
            delay_model_samples = np.array(delay_model_samples)
            delay_model_samples = np.transpose(np.array(delay_model_samples))
            
            delay_sim_res = delay_model_samples
            LO_delay = delay_sim_res[D-LO:]
            LO_truth = ts[len(ts)-LO:]
           
           # sim_results_mse.append([mean_absolute_error(np.mean(LO_delay,axis=1),LO_truth)])
            delay_cp = 0
            
            LO_delay_low = []
            LO_delay_high = []
            for i in range(LO):
                LO_delay_ci = np.round(np.percentile(LO_delay[i],[2.5,97.5]))
                LO_delay_low.append(LO_delay_ci[0])
                LO_delay_high.append(LO_delay_ci[1])
    
                if LO_delay_ci[0] <= LO_truth[i] <= LO_delay_ci[1]:
                    delay_cp +=1
        
            offset = 1
            #kernel = GPy.kern.RBF(input_dim=1, variance=.0001, lengthscale=1.)
            Y = delay_model_samples
            X = []
            for i in range(len(delay_model_samples)):
                X.append(i*np.ones(N_SIM))
            X = np.array(X)
            proc_model_training_data = np.append(train_n_t_d[:len(ts)-D],np.mean(Y,axis=1)[:D-offset])
            
            myDLM = dlm(proc_model_training_data)    
            #myDLM = myDLM + trend(degree=1, discount=0.95, name='trend1')

            myDLM = myDLM + autoReg(degree=3, data=proc_model_training_data, name='ar3', w=1.0)
            myDLM.fit()
                                                 
            (predictMean, predictVar) = myDLM.predictN(N=offset)
        
#             plt.plot(range(len(Y)),np.mean(Y,axis=1))
#             plt.plot(range(len(Y)),np.append(np.mean(Y,axis=1)[:D-1],predictMean))
#             plt.plot(range(len(Y)),ts[sim_num-D:(sim_num)])
                                                 
                                                 
#             plt.show()
           # sys.exit()

           
            # this this generate y values for our xvalues by our interpolator
            # it will MISS values outsite of the x window (less than 3, greater than 33)
            # There might be a better approach, but you can run a for loop
            #and if the value is out of the range, use f(min(lowess_x)) or f(max(lowess_x))
           
            gpy_traj_samps = []
            for i in range(N_SIM):
                gpy_traj_samps.append(np.random.normal(predictMean,1))
            gpy_traj_samps = np.array(gpy_traj_samps).reshape((offset,N_SIM))
           
        
            gpy_traj = np.append(delay_model_samples[:(D-offset),],gpy_traj_samps,axis=0)
           
           
            
            joint_samples = np.append(gpy_traj,delay_model_samples,axis=1)
            print (joint_samples.shape)
            from sklearn.preprocessing import normalize
            normed_matrix = joint_samples/np.max(joint_samples)
            
            import GPy
            k1 = GPy.kern.RBF(1, 1., 2.)
            k2 = GPy.kern.Matern32(1, 0.5, 0.2)

            # product of kernels
            k_prod = k1 * k2
            X = []
            for i in range(joint_samples.shape[0]):
                X.append(i*np.ones(joint_samples.shape[1]))
            X = np.array(X)
            
            m = GPy.models.GPRegression(X.flatten().reshape((-1,1)),normed_matrix.flatten().reshape((-1,1)),k_prod)
            m.optimize(messages=True)
            gpy_traj = m.predict(np.arange(D).reshape((-1,1)))[0]*np.max(joint_samples)
            
            #sys.exit()
                
        
        
        
            plt.fill_between(range(sim_num,LO+sim_num),LO_delay_low,LO_delay_high,alpha=1,color='blue')
            #plt.plot(range(sim_num,sim_num+LO),np.sum(delayed_data,axis=1),color='yellow',alpha=.1)
            plt.plot(range(sim_num,sim_num+LO),LO_truth,color='red')
            plt.plot(range(sim_num,sim_num+LO),gpy_traj,color='brown')
            plt.legend(("Truth","Adj","Delay"))
            plt.ylabel("Incidence")
            plt.xlabel("Time")
            plt.show()
            
            
            
            
            sim_results_mse.append([mean_absolute_error(LO_truth,np.mean(gpy_traj,axis=1)),mean_absolute_error(LO_truth,np.mean(delay_model_samples,axis=1))])
            print (sim_results_mse[-1])
            #sys.exit()
            #gp_cp = 1.*gp_cp/LO
            #fcast_cp = 1.*fcast_cp/LO
            delay_cp = 1.*delay_cp/LO
            #print (sim_results_mse[-1])
            print (delay_cp)#,fcast_cp,av_cp)
            #sim_results_pi.append([delay_cp,gp_cp])
# Out:
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s00  0000   1.865226e+03           nan
#     05s42  0004   2.986287e+08   1.186025e+15
#     24s44  0014  -2.803040e+03   2.779129e+03
#     29s66  0017  -2.805333e+03   8.822902e-02
#  01m11s39  0050  -2.815349e+03   1.600255e-02
#  01m17s02  0055  -2.815355e+03   3.535211e-06
#  01m22s71  0060  -2.815357e+03   2.907491e-02
# Runtime:  01m22s71
# Optimization status: Converged
# [1.324015166490447, 1.55503]
# 0.9
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     02s53  0002   1.156652e+03   6.129791e+05
#     11s35  0009  -3.174627e+03   2.477695e+02
#     22s91  0019  -3.178469e+03   6.667352e-03
#  01m03s91  0055  -3.187025e+03   6.629849e-02
#  01m13s00  0063  -3.187035e+03   2.441479e-02
#  01m24s36  0073  -3.187036e+03   3.008085e-04
#  01m32s35  0080  -3.187036e+03   2.363150e-04
# Runtime:  01m32s35
# Optimization status: Converged
# [0.9111864040985083, 0.9831099999999996]
# 0.9
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     04s88  0003  -2.305966e+03   5.140204e+05
#     14s33  0011  -2.868451e+03   4.015701e+01
#     21s10  0017  -2.871134e+03   1.581426e+00
#     59s76  0050  -2.882569e+03   4.240330e-01
#  01m10s13  0059  -2.882313e+03   5.895875e+02
#  01m12s44  0061  -2.882616e+03   5.770962e-03
# Runtime:  01m12s44
# Optimization status: Converged
# [0.7798725654731988, 0.8468100000000003]
# 0.8
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     07s34  0006  -3.247915e+03   1.610019e+06
#     17s82  0015  -3.699880e+03   1.034411e-02
#     24s65  0021  -3.703956e+03   3.010173e+01
#     32s62  0028  -3.707192e+03   9.879365e-01
#     43s91  0038  -3.708156e+03   1.716726e-01
#     51s91  0045  -3.708296e+03   6.939660e-03
#  01m03s24  0055  -3.708321e+03   7.462230e-06
#  01m07s78  0059  -3.708322e+03   9.263200e-05
# Runtime:  01m07s78
# Optimization status: Converged
# [0.9349859615905567, 0.9399200000000004]
# 0.7
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     09s80  0008   3.969785e+07   9.891449e+14
#     22s46  0019  -3.369037e+03   1.208474e+02
#     57s42  0049  -3.376405e+03   9.339833e-01
#  01m16s78  0066  -3.376436e+03   5.273445e-03
#  01m24s69  0073  -3.376436e+03   5.719861e-05
#  01m29s34  0077  -3.376436e+03   3.137906e-05
# Runtime:  01m29s34
# Optimization status: Converged
# [1.7751850358318748, 1.7770500000000005]
# 0.7
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     09s89  0007  -1.485949e+03   8.287238e+05
#     28s21  0021  -3.221216e+03   2.214019e-01
#     31s59  0024  -3.221216e+03   1.627155e-03
# Runtime:     31s59
# Optimization status: Converged
# [3.408598280310437, 3.7689600000000008]
# 0.8
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     01s34  0001   1.864856e+03   3.926551e+05
#     06s21  0005  -2.253216e+03   4.396612e+05
#     20s04  0017  -2.697713e+03   8.186113e+03
#     25s75  0022  -2.703421e+03   6.264231e-03
#  01m13s28  0063  -2.707107e+03   1.064836e-01
#  01m23s52  0072  -2.707110e+03   2.392688e-03
#  01m29s14  0077  -2.707110e+03   1.326769e-03
# Runtime:  01m29s14
# Optimization status: Converged
# [8.108351738884465, 8.43792]
# 0.7
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     02s74  0002   1.154651e+03   6.142198e+05
#     12s20  0010  -3.409111e+03   1.190398e+03
#     27s09  0023  -3.431161e+03   1.125266e+00
#     47s49  0041  -3.431901e+03   1.301160e-02
#  01m16s02  0066  -3.431915e+03   8.106443e-04
#  01m24s08  0073  -3.431915e+03   1.074861e-03
# Runtime:  01m24s08
# Optimization status: Converged
# [11.270434752692845, 13.57106]
# 0.7
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     09s00  0007  -2.394906e+03   5.506620e+02
#     23s74  0020  -2.409161e+03   6.075883e-03
#  01m06s70  0058  -2.415867e+03   2.199551e-01
#  01m16s84  0067  -2.415872e+03   3.127159e-03
#  01m21s32  0071  -2.415872e+03   4.534074e-03
# Runtime:  01m21s32
# Optimization status: Converged
# [12.126356894728689, 23.855870000000003]
# 0.9
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     07s33  0006  -3.181387e+03   2.513807e+06
#     19s12  0016  -3.831099e+03   9.009687e+00
#     54s61  0047  -3.833475e+03   2.568950e+00
#  01m26s34  0075  -3.833599e+03   1.725340e-02
#  01m54s82  0100  -3.833601e+03   7.808839e-03
# Runtime:  01m54s82
# Optimization status: Converged
# [38.6632890034547, 38.151779999999995]
# 0.8
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     08s65  0007  -2.115074e+03   5.673108e+05
#     26s51  0021  -2.802659e+03   5.819835e-01
#  01m06s41  0056  -2.812058e+03   1.261155e-01
#  01m11s01  0060  -2.812063e+03   9.057624e-06
#  01m15s59  0064  -2.812063e+03   2.655421e-04
# Runtime:  01m15s59
# Optimization status: Converged
# [17.157065035189593, 33.76575000000001]
# 0.9
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     03s61  0003  -1.943372e+03   1.262129e+05
#     16s17  0014  -2.036952e+03   7.372358e+03
#     19s53  0017  -2.040956e+03   4.701343e-01
#     57s03  0050  -2.050936e+03   2.546188e-01
#  01m11s82  0063  -2.051038e+03   3.535223e-02
#  01m23s15  0073  -2.051039e+03   2.910713e-04
# Runtime:  01m23s15
# Optimization status: Converged
# [36.81107487526005, 47.80884999999999]
# 0.8
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s00  0000   1.867870e+03           nan
#     06s02  0005   5.161450e+03   9.307885e+07
#     17s41  0015  -2.140096e+03   1.995999e+01
#     50s22  0044  -2.149832e+03   4.648134e-01
#     57s07  0050  -2.149915e+03   2.024961e-01
#  01m11s87  0063  -2.149932e+03   9.642081e-04
#  01m17s55  0068  -2.149932e+03   2.242690e-04
# Runtime:  01m17s55
# Optimization status: Converged
# [22.744947428953026, 43.723530000000004]
# 0.9
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     06s24  0005  -2.257671e+03   4.454873e+05
#     21s18  0018  -2.718919e+03   1.298935e+02
#     24s60  0021  -2.719061e+03   7.743335e-03
#     57s51  0050  -2.726326e+03   1.461368e-02
#  01m04s28  0056  -2.726353e+03   4.003127e-04
#  01m10s01  0061  -2.726357e+03   1.168313e-04
# Runtime:  01m10s01
# Optimization status: Converged
# [37.89388075394611, 70.56614]
# 0.8
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     08s54  0007  -2.367504e+03   7.201140e+02
#     14s41  0012  -2.369943e+03   3.604520e+02
#     22s30  0019  -2.379921e+03   1.597889e+03
#     47s41  0041  -2.387755e+03   3.624816e+00
#  01m25s12  0074  -2.388115e+03   2.523928e-02
#  01m29s65  0078  -2.388117e+03   2.427991e-04
#  01m44s35  0091  -2.388118e+03   6.425190e-05
# Runtime:  01m44s35
# Optimization status: Converged
# [41.48043705485924, 79.28724]
# 0.6
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     05s01  0004   4.399555e+07   2.576744e+13
#     15s50  0013  -4.707381e+03   2.748594e+01
#     30s22  0026  -4.763018e+03   2.360765e-01
#     39s42  0034  -4.763025e+03   4.263880e-02
#     42s80  0037  -4.763025e+03   2.361051e-04
# Runtime:     42s80
# Optimization status: Converged
# [5.182666635576213e+35, 4.886657794571806e+38]
# 0.9
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     10s99  0009  -4.686502e+03   3.606623e+04
#     30s41  0026  -4.763018e+03   2.024062e-01
#     36s04  0031  -4.763025e+03   4.246188e-06
#     39s53  0034  -4.763025e+03   1.714524e-04
#     42s95  0037  -4.763025e+03   4.598908e-04
# Runtime:     42s95
# Optimization status: Converged
# [1.9488063601094632e+28, 1.6907767924106898e+31]
# 0.9
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     06s60  0005  -2.540299e+03   8.953972e+05
#     20s30  0017  -4.710482e+03   4.197091e+03
#     30s69  0026  -4.763018e+03   3.491817e-01
#     32s99  0028  -4.763023e+03   1.245126e-01
#     41s19  0035  -4.763025e+03   3.446281e-03
#     43s96  0037  -4.763025e+03   5.825738e-05
# Runtime:     43s96
# Optimization status: Converged
# [4.184156788648431e+34, 4.941688360243672e+37]
# 0.9
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     04s09  0003  -2.538043e+03   8.955658e+05
#     17s02  0014  -4.707419e+03   3.544632e+01
#     30s82  0026  -4.763019e+03   1.206699e-01
#     42s59  0036  -4.763025e+03   7.005054e-06
#     43s74  0037  -4.763025e+03   7.005054e-06
# Runtime:     43s74
# Optimization status: Converged
# [2.156475846864066e+31, 2.209110106306055e+34]
# 1.0
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     05s57  0004   4.399493e+07   2.576671e+13
#     19s76  0016  -4.708037e+03   5.510782e+02
#     31s62  0026  -4.763016e+03   3.321315e-01
#     38s58  0032  -4.763022e+03   3.315512e-05
#     41s91  0035  -4.763023e+03   2.972081e-02
# Runtime:     41s91
# Optimization status: Converged
# [2.8526413050214455e+31, 1.217595303861508e+34]
# 0.9
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     11s46  0007  -2.246417e+03   9.404712e+03
#     29s35  0020  -2.258384e+03   2.169436e-01
#  01m11s40  0052  -2.266390e+03   3.667446e-02
#  01m21s78  0061  -2.266410e+03   1.671881e-03
# Runtime:  01m21s78
# Optimization status: Converged
# [43.91021982582747, 81.28177000000008]
# 0.9
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s00  0000   1.861450e+03           nan
#     03s98  0003  -2.538043e+03   8.955658e+05
#     17s69  0013  -4.707381e+03   2.748514e+01
#     40s13  0026  -4.763018e+03   2.951734e-01
#     52s29  0036  -4.763025e+03   5.961522e-03
# Runtime:     52s29
# Optimization status: Converged
# [3.36537000700654e+35, 1.5404586636283446e+38]
# 0.9
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     06s55  0005  -2.500867e+03   8.323844e+05
#     26s05  0017  -4.124390e+03   2.071438e-02
#  01m13s14  0048  -4.133587e+03   8.062086e-01
#  01m21s27  0054  -4.133627e+03   2.901999e-03
#  01m27s15  0058  -4.133632e+03   3.826321e-03
#  01m47s81  0071  -4.133636e+03   2.453380e-07
#  01m49s17  0072  -4.133636e+03   2.453380e-07
# Runtime:  01m49s17
# Optimization status: Converged
# [73.40785090150175, 71.94149999999999]
# 0.5
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     05s90  0004   9.364723e+07   1.165703e+14
#     20s85  0016  -3.951483e+03   1.932326e-01
#     54s14  0043  -3.960317e+03   3.481211e+00
#  01m14s94  0059  -3.960454e+03   7.017112e-03
#  01m23s36  0066  -3.960455e+03   3.164323e-04
# Runtime:  01m23s36
# Optimization status: Converged
# [26.26967448275608, 27.084089999999975]
# 0.5
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     08s75  0006  -5.847438e+02   3.353260e+07
#     26s79  0018  -4.466030e+03   7.191120e-01
#  01m15s99  0052  -4.474421e+03   2.262663e+00
#  01m26s15  0060  -4.474460e+03   1.095412e-01
#  01m43s39  0073  -4.474470e+03   3.660543e-02
#  01m52s86  0080  -4.474470e+03   3.124560e-05
# Runtime:  01m52s86
# Optimization status: Converged
# [9.060240397878676, 11.667799999999952]
# 0.7
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     03s16  0002   1.155652e+03   6.179043e+05
#     11s29  0008  -4.679985e+03   1.127042e+06
#     28s85  0020  -5.019333e+03   2.530601e+00
#  01m16s88  0056  -5.026859e+03   8.243496e-02
#  01m34s17  0069  -5.026878e+03   1.041924e-02
#  01m42s11  0075  -5.026878e+03   1.769100e-03
# Runtime:  01m42s11
# Optimization status: Converged
# [6.882598032117357, 8.558490000000017]
# 0.6
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# (10, 200)
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     03s29  0002   1.154988e+03   6.182501e+05
#     11s93  0008  -4.636601e+03   3.669291e+06
#     30s02  0021  -5.484566e+03   2.557900e-02
#     38s48  0028  -5.484703e+03   2.136595e+02
# Runtime:     38s48
# Optimization status: None
#
# KeyboardInterrupt caught, calling on_optimization_end() to round things up
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-242-81eafb03c86b> in <module>()
#     143
#     144             m = GPy.models.GPRegression(X.flatten().reshape((-1,1)),normed_matrix.flatten().reshape((-1,1)),k_prod)
# --> 145             m.optimize(messages=True)
#     146             gpy_traj = m.predict(np.arange(D).reshape((-1,1)))[0]*np.max(joint_samples)
#     147
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/GPy/core/gp.pyc in optimize(self, optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     563         self.inference_method.on_optimization_start()
#     564         try:
# --> 565             ret = super(GP, self).optimize(optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     566         except KeyboardInterrupt:
#     567             print("KeyboardInterrupt caught, calling on_optimization_end() to round things up")
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/paramz/model.pyc in optimize(self, optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     109
#     110         with VerboseOptimization(self, opt, maxiters=max_iters, verbose=messages, ipython_notebook=ipython_notebook, clear_after_finish=clear_after_finish) as vo:
# --> 111             opt.run(start, f_fp=self._objective_grads, f=self._objective, fp=self._grads)
#     112
#     113         self.optimization_runs.append(opt)
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/paramz/optimization/optimization.pyc in run(self, x_init, **kwargs)
#      49     def run(self, x_init, **kwargs):
#      50         start = dt.datetime.now()
# ---> 51         self.opt(x_init, **kwargs)
#      52         end = dt.datetime.now()
#      53         self.time = str(end - start)
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/paramz/optimization/optimization.pyc in opt(self, x_init, f_fp, f, fp)
#     122             opt_dict['factr'] = self.bfgs_factor
#     123
# --> 124         opt_result = optimize.fmin_l_bfgs_b(f_fp, x_init, maxfun=self.max_iters, maxiter=self.max_iters, **opt_dict)
#     125         self.x_opt = opt_result[0]
#     126         self.f_opt = f_fp(self.x_opt)[0]
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/scipy/optimize/lbfgsb.pyc in func_and_grad(x)
#     283     else:
#     284         def func_and_grad(x):
# --> 285             f = fun(x, *args)
#     286             g = jac(x, *args)
#     287             return f, g
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/scipy/optimize/optimize.pyc in __call__(self, x, *args)
#      61     def __call__(self, x, *args):
#      62         self.x = numpy.asarray(x).copy()
# ---> 63         fg = self.fun(x, *args)
#      64         self.jac = fg[1]
#      65         return fg[0]
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/paramz/model.pyc in _objective_grads(self, x)
#     268     def _objective_grads(self, x):
#     269         try:
# --> 270             self.optimizer_array = x
#     271             obj_f, self.obj_grads = self.objective_function(), self._transform_gradients(self.objective_function_gradients())
#     272             self._fail_count = 0
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/paramz/parameterized.pyc in __setattr__(self, name, val)
#     334                 param = self.parameters[pnames.index(name)]
#     335                 param[:] = val; return
# --> 336         return object.__setattr__(self, name, val);
#     337
#     338     #===========================================================================
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/paramz/core/parameter_core.pyc in optimizer_array(self, p)
#     116
#     117         self._optimizer_copy_transformed = False
# --> 118         self.trigger_update()
#     119
#     120     def _trigger_params_changed(self, trigger_parent=True):
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/paramz/core/updateable.pyc in trigger_update(self, trigger_parent)
#      77             #print "Warning: updates are off, updating the model will do nothing"
#      78             return
# ---> 79         self._trigger_params_changed(trigger_parent)
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/paramz/core/parameter_core.pyc in _trigger_params_changed(self, trigger_parent)
#     126         """
#     127         [p._trigger_params_changed(trigger_parent=False) for p in self.parameters if not p.is_fixed]
# --> 128         self.notify_observers(None, None if trigger_parent else -np.inf)
#     129
#     130     def _size_transformed(self):
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/paramz/core/observable.pyc in notify_observers(self, which, min_priority)
#      89                 which = self
#      90             if min_priority is None:
# ---> 91                 [callble(self, which=which) for _, _, callble in self.observers]
#      92             else:
#      93                 for p, _, callble in self.observers:
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/paramz/core/parameter_core.pyc in _parameters_changed_notification(self, me, which)
#     496         """
#     497         self._optimizer_copy_transformed = False # tells the optimizer array to update on next request
# --> 498         self.parameters_changed()
#     499     def _pass_through_notify_observers(self, me, which=None):
#     500         self.notify_observers(which=which)
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/GPy/core/gp.pyc in parameters_changed(self)
#     191             this method yourself, there may be unexpected consequences.
#     192         """
# --> 193         self.posterior, self._log_marginal_likelihood, self.grad_dict = self.inference_method.inference(self.kern, self.X, self.likelihood, self.Y_normalized, self.mean_function, self.Y_metadata)
#     194         self.likelihood.update_gradients(self.grad_dict['dL_dthetaL'])
#     195         self.kern.update_gradients_full(self.grad_dict['dL_dK'], self.X)
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/GPy/inference/latent_function_inference/exact_gaussian_inference.pyc in inference(self, kern, X, likelihood, Y, mean_function, Y_metadata, K, variance, Z_tilde)
#      38
#      39         if K is None:
# ---> 40             K = kern.K(X)
#      41
#      42         Ky = K.copy()
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/GPy/kern/src/kernel_slice_operations.pyc in wrap(self, X, X2, *a, **kw)
#      84     def wrap(self, X, X2 = None, *a, **kw):
#      85         with _Slice_wrap(self, X, X2) as s:
# ---> 86             ret = f(self, s.X, s.X2, *a, **kw)
#      87         return ret
#      88     return wrap
#
# <decorator-gen-140> in K(self, X, X2, which_parts)
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/paramz/caching.pyc in g(obj, *args, **kw)
#     281             else:
#     282                 cacher = cache[self.f] = Cacher(self.f, self.limit, self.ignore_args, self.force_kwargs, cacher_enabled=cache.caching_enabled)
# --> 283             return cacher(*args, **kw)
#     284         g.__name__ = f.__name__
#     285         g.__doc__ = f.__doc__
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/paramz/caching.pyc in __call__(self, *args, **kw)
#     177             # If we need to compute, we compute the operation, but fail gracefully, if the operation has an error:
#     178             try:
# --> 179                 new_output = self.operation(*args, **kw)
#     180             except:
#     181                 self.reset()
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/GPy/kern/src/prod.pyc in K(self, X, X2, which_parts)
#      47             # if only one part is given
#      48             which_parts = [which_parts]
# ---> 49         return reduce(np.multiply, (p.K(X, X2) for p in which_parts))
#      50
#      51     @Cache_this(limit=3, force_kwargs=['which_parts'])
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/GPy/kern/src/prod.pyc in <genexpr>((p,))
#      47             # if only one part is given
#      48             which_parts = [which_parts]
# ---> 49         return reduce(np.multiply, (p.K(X, X2) for p in which_parts))
#      50
#      51     @Cache_this(limit=3, force_kwargs=['which_parts'])
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/GPy/kern/src/kernel_slice_operations.pyc in wrap(self, X, X2, *a, **kw)
#      84     def wrap(self, X, X2 = None, *a, **kw):
#      85         with _Slice_wrap(self, X, X2) as s:
# ---> 86             ret = f(self, s.X, s.X2, *a, **kw)
#      87         return ret
#      88     return wrap
#
# <decorator-gen-144> in K(self, X, X2)
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/paramz/caching.pyc in g(obj, *args, **kw)
#     281             else:
#     282                 cacher = cache[self.f] = Cacher(self.f, self.limit, self.ignore_args, self.force_kwargs, cacher_enabled=cache.caching_enabled)
# --> 283             return cacher(*args, **kw)
#     284         g.__name__ = f.__name__
#     285         g.__doc__ = f.__doc__
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/paramz/caching.pyc in __call__(self, *args, **kw)
#     177             # If we need to compute, we compute the operation, but fail gracefully, if the operation has an error:
#     178             try:
# --> 179                 new_output = self.operation(*args, **kw)
#     180             except:
#     181                 self.reset()
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/GPy/kern/src/stationary.pyc in K(self, X, X2)
#     105         """
#     106         r = self._scaled_dist(X, X2)
# --> 107         return self.K_of_r(r)
#     108
#     109     @Cache_this(limit=3, ignore_args=())
#
# /Users/gcgibson/anaconda/lib/python2.7/site-packages/GPy/kern/src/stationary.pyc in K_of_r(self, r)
#     401
#     402     def K_of_r(self, r):
# --> 403         return self.variance * (1. + np.sqrt(3.) * r) * np.exp(-np.sqrt(3.) * r)
#     404
#     405     def dK_dr(self,r):
#
# KeyboardInterrupt:

# %%
sim_results_mse = np.array(sim_results_mse)
#for i in sim_results_mse:
 #   print(i)
print (sim_results_mse)
print np.mean(sim_results_mse,axis=0)
# Out:
# [[  1.01410321   1.2164    ]
#  [  0.79277573   0.8453    ]
#  [  0.61179242   0.6633    ]
#  [  0.93062088   0.9395    ]
#  [  1.83208564   1.8252    ]
#  [  2.7667017    3.0519    ]
#  [  7.6914173    7.9636    ]
#  [ 10.57977489  11.8309    ]
#  [ 11.97214162  19.4861    ]
#  [ 39.43877464  39.0469    ]
#  [ 22.40591156  32.1527    ]
#  [ 21.56501848  39.6629    ]
#  [ 20.93803872  38.5325    ]
#  [ 31.05370286  52.8954    ]
#  [ 33.03608001  62.1827    ]
#  [151.99514521 175.7766    ]
#  [ 80.63815488  59.2128    ]
#  [ 86.36845332  74.5807    ]
#  [ 60.11092023  52.9022    ]
#  [167.99922213 266.5042    ]
#  [ 39.48802678  72.9394    ]
#  [ 42.59381886  43.933     ]
#  [ 73.13325347  71.6921    ]
#  [ 25.59315818  26.196     ]
#  [  9.78033879  12.3833    ]
#  [  5.95893051   7.5556    ]
#  [  5.78560538   6.4716    ]
#  [  3.67964302   4.05      ]
#  [  4.51622746   5.1346    ]
#  [  5.47869008   5.3838    ]
#  [  4.74994861   4.9703    ]
#  [  3.37449625   4.0549    ]
#  [ 12.37502325  27.3657    ]
#  [  8.57154306   9.4489    ]
#  [ 10.08831068  11.1702    ]
#  [ 19.19921672  21.0831    ]
#  [ 29.90488701  32.607     ]
#  [ 59.26883109  67.7549    ]
#  [ 87.21807769 101.0279    ]
#  [ 65.38005109 103.4753    ]
#  [ 59.1862966  105.6373    ]
#  [ 51.09540233  84.5183    ]
#  [ 53.92860492  47.7962    ]
#  [ 33.26344519  41.7369    ]
#  [ 28.05930076  32.7673    ]
#  [ 18.65738226  24.8336    ]
#  [ 14.63691645  19.4077    ]
#  [ 24.47741926  24.1157    ]]
# [32.35799336 40.84963333]

# %%
from tabulate import tabulate

print np.mean(sim_results_pi,axis=0)
sim_results_mse = np.array(sim_results_mse)

sim_results_mse_formatted = []
for i in range(len(sim_results_mse)):
    sim_results_mse_formatted.append([i+30,sim_results_mse[i][0],sim_results_mse[i][2]])
    
print(tabulate(sim_results_mse_formatted, tablefmt="latex", floatfmt=".2f"))

print np.round(np.mean(sim_results_mse,axis=0))

wins = 0
for i in range(len(sim_results_mse)):
    if sim_results_mse[i][2] < sim_results_mse[i][0]:
        wins +=1
        
print (1.*wins/(len(sim_results_mse)))

# %%
from scipy.special import expit
import matplotlib.pyplot as pltq

variance_level_results = []
import sys
from pydlm import dlm, trend, seasonality, dynamic, autoReg, longSeason
from sklearn.metrics import mean_squared_error

cv_mse = []
season_data = []
sim_results_mse = []
sim_results_pi = []
for i in range(3):
    season_data.append(n_t_d[i:(i+26)])
    
season_data = np.array(season_data).reshape((3,-1,26))

print (season_data.shape)

for season_for_leave_out in np.arange(3):
        sim_n_t_d = season_data#[:cutoff]

        train = [sim_n_t_d[x] for x in range(3) if x not in [season_for_leave_out]]
        test = sim_n_t_d[season_for_leave_out]
        
        train = np.array(train)
        train_n_t_d = train.reshape((-1,D))
        ts = train_n_t_d.sum(axis=1)

        data_to_be_scaled_down  = test[len(test)-D:]
       
        delayed_data = []
        count = D
        for i in range(len(data_to_be_scaled_down)):
            tmp = data_to_be_scaled_down[i][:count].tolist()
            while len(tmp) <D:
                tmp.append(0)
            delayed_data.append(tmp)
            count -=1 


        training_data = np.append(train_n_t_d[:len(ts)-D],delayed_data,axis=0)

        k = np.array(train_n_t_d).shape[1 ]
        alphas = np.ones(k)

        for i in range(len(ts)-D):
            alphas += train_n_t_d[i]



        #######
        # MODEL 1: Delay
        ########
        delay_model_samples = []
        for s_ in range(N_SIM):
            model_1_delay = []
            count = D
            p_vec_noise = np.random.dirichlet(alphas)
            for i in range(len(delayed_data)):
                delay_forecast = np.sum(delayed_data[i])/np.sum(p_vec_noise[:count])
                model_1_delay.append(np.round(delay_forecast,2))
                count -= 1
            delay_model_samples.append(model_1_delay)

        delay_model_samples = np.array(delay_model_samples)


        #######
        # MODEL 2 : Forecast
        ########

        LO=D
        process_training_data = np.append(ts[:len(ts)-D],model_1_delay[:D-LO],axis=0)
        from pydlm import dlm, trend, seasonality, dynamic, autoReg, longSeason
        myDLM = dlm(process_training_data)
       # myDLM = myDLM + seasonality(26, name='7day', w=1.0)
        myDLM = myDLM + autoReg(degree=2, data=process_training_data, name='ar2', w=1.0)
        myDLM.fit()
        (process_model_forecast, predictVar) = myDLM.predictN(N=LO, date=myDLM.n-1)

        #######
        # MODEL 2
        ########
        forecast_model_samples = []
        for s_ in range(N_SIM):
            model_2_delay = []
            count = D
            for i in np.arange(LO,0,-1):
                tmp = np.random.normal(process_model_forecast[LO-i],np.sqrt(predictVar[LO-i]))
                model_2_delay.append(np.round(tmp,2))
                count -= 1

            forecast_model_samples.append(np.append(model_1_delay[:D-LO],model_2_delay))

        forecast_model_samples = np.array(forecast_model_samples)


        model_average = bayes_estimate_prob(np.sum(delayed_data,axis=1),forecast_model_samples,alphas,LO,N_SIM)
            
        delay_model_samples = np.transpose(np.array(delay_model_samples))
        forecast_model_samples = np.transpose(np.array(forecast_model_samples))
            
        delay_sim_res = delay_model_samples
        fcast_sim_res = forecast_model_samples
        avg_sim_res = model_average
        LO_av = np.array(avg_sim_res).reshape((LO,-1))
        LO_delay = delay_sim_res[D-LO:]
        LO_fcast = fcast_sim_res[D-LO:]
        LO_truth = ts[len(ts)-LO:]
        #print (np.mean(LO_delay,axis=1),np.mean(LO_fcast,axis=1),LO_truth\
               #,np.mean(LO_av,axis=1))
        #sys.exit()
        sim_results_mse.append([mean_absolute_error(np.mean(LO_delay,axis=1),LO_truth),\
                               mean_absolute_error(np.mean(LO_fcast,axis=1),LO_truth),\
                               mean_absolute_error(np.mean(LO_av,axis=1),LO_truth)])
        print (sim_results_mse[-1])
        av_cp = 0
        fcast_cp = 0
        delay_cp = 0
        for i in range(LO):
            LO_av_ci = np.round(np.percentile(LO_av[i],[2.5,97.5]))
            LO_fcast_ci = np.round(np.percentile(LO_fcast[i],[2.5,97.5]))
            LO_delay_ci = np.round(np.percentile(LO_delay[i],[2.5,97.5]))
            print (LO_delay_ci,LO_fcast_ci,LO_av_ci, LO_truth[i])
            if LO_av_ci[0] <= LO_truth[i] <= LO_av_ci[1]:
                av_cp +=1

            if LO_fcast_ci[0] <= LO_truth[i] <= LO_fcast_ci[1]:
                fcast_cp +=1

            if LO_delay_ci[0] <= LO_truth[i] <= LO_delay_ci[1]:
                delay_cp +=1


        av_cp = 1.*av_cp/LO
        fcast_cp = 1.*fcast_cp/LO
        delay_cp = 1.*delay_cp/LO

        print (delay_cp,fcast_cp,av_cp)
        sim_results_pi.append([delay_cp,fcast_cp,av_cp])
# Out:
# (3, 26, 26)
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# [15.051926923076925, 32.414211538461544, 14.958975435630133]
# (array([4., 4.]), array([-20.,  34.]), array([4., 4.]), 5.0)
# (array([5., 5.]), array([-18.,  29.]), array([5., 5.]), 4.0)
# (array([5., 5.]), array([-16.,  27.]), array([5., 5.]), 2.0)
# (array([3., 3.]), array([-23.,  20.]), array([3., 3.]), 1.0)
# (array([2., 2.]), array([-23.,  21.]), array([2., 2.]), 0.0)
# (array([1., 1.]), array([-27.,  26.]), array([1., 1.]), 2.0)
# (array([0., 0.]), array([-25.,  25.]), array([0., 0.]), 5.0)
# (array([2., 2.]), array([-26.,  25.]), array([2., 2.]), 6.0)
# (array([5., 5.]), array([-25.,  22.]), array([5., 6.]), 17.0)
# (array([5., 5.]), array([-26.,  24.]), array([5., 6.]), 37.0)
# (array([16., 17.]), array([-21.,  26.]), array([14., 19.]), 59.0)
# (array([36., 37.]), array([-24.,  26.]), array([30., 43.]), 99.0)
# (array([58., 60.]), array([-27.,  20.]), array([48., 71.]), 77.0)
# (array([ 97., 101.]), array([-27.,  25.]), array([ 80., 120.]), 90.0)
# (array([77., 81.]), array([-20.,  21.]), array([63., 96.]), 90.0)
# (array([93., 97.]), array([-19.,  22.]), array([ 76., 116.]), 85.0)
# (array([89., 94.]), array([-27.,  27.]), array([ 72., 112.]), 81.0)
# (array([86., 90.]), array([-21.,  26.]), array([ 69., 108.]), 63.0)
# (array([69., 73.]), array([-22.,  24.]), array([55., 88.]), 28.0)
# (array([65., 68.]), array([-22.,  30.]), array([52., 83.]), 27.0)
# (array([30., 32.]), array([-29.,  26.]), array([24., 39.]), 19.0)
# (array([26., 28.]), array([-31.,  25.]), array([20., 34.]), 15.0)
# (array([21., 22.]), array([-29.,  22.]), array([15., 28.]), 13.0)
# (array([22., 24.]), array([-24.,  21.]), array([12., 33.]), 8.0)
# (array([5., 6.]), array([-24.,  26.]), array([3., 9.]), 6.0)
# (array([0., 0.]), array([-25.,  21.]), array([1., 3.]), 9.0)
# (0.038461538461538464, 0.6153846153846154, 0.19230769230769232)
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# [9.170815384615384, 32.66074230769231, 8.950576920123298]
# (array([5., 5.]), array([-20.,  35.]), array([5., 5.]), 5.0)
# (array([5., 5.]), array([-20.,  29.]), array([5., 5.]), 4.0)
# (array([4., 4.]), array([-17.,  34.]), array([4., 4.]), 2.0)
# (array([2., 2.]), array([-21.,  32.]), array([2., 2.]), 1.0)
# (array([1., 1.]), array([-18.,  22.]), array([1., 1.]), 0.0)
# (array([0., 0.]), array([-21.,  23.]), array([0., 0.]), 2.0)
# (array([2., 2.]), array([-21.,  33.]), array([2., 2.]), 5.0)
# (array([5., 5.]), array([-21.,  23.]), array([5., 6.]), 6.0)
# (array([5., 5.]), array([-29.,  22.]), array([5., 6.]), 17.0)
# (array([17., 17.]), array([-20.,  30.]), array([15., 19.]), 37.0)
# (array([37., 38.]), array([-21.,  25.]), array([31., 44.]), 59.0)
# (array([61., 64.]), array([-27.,  23.]), array([51., 73.]), 99.0)
# (array([100., 104.]), array([-28.,  19.]), array([ 83., 121.]), 77.0)
# (array([78., 81.]), array([-25.,  29.]), array([63., 95.]), 90.0)
# (array([94., 98.]), array([-25.,  29.]), array([ 76., 114.]), 90.0)
# (array([89., 94.]), array([-24.,  19.]), array([ 72., 110.]), 85.0)
# (array([87., 91.]), array([-28.,  23.]), array([ 69., 107.]), 81.0)
# (array([70., 73.]), array([-24.,  23.]), array([56., 87.]), 63.0)
# (array([65., 69.]), array([-22.,  25.]), array([52., 82.]), 28.0)
# (array([31., 32.]), array([-17.,  20.]), array([24., 38.]), 27.0)
# (array([26., 27.]), array([-27.,  25.]), array([20., 33.]), 19.0)
# (array([19., 21.]), array([-20.,  23.]), array([15., 25.]), 15.0)
# (array([17., 18.]), array([-22.,  24.]), array([12., 23.]), 13.0)
# (array([13., 14.]), array([-23.,  22.]), array([ 7., 19.]), 8.0)
# (array([6., 7.]), array([-25.,  27.]), array([3., 9.]), 6.0)
# (array([0., 0.]), array([-20.,  27.]), array([3., 5.]), 9.0)
# (0.07692307692307693, 0.5769230769230769, 0.46153846153846156)
# Starting forward filtering...
# Forward fitering completed.
# Starting backward smoothing...
# Backward smoothing completed.
# [8.953907692307691, 31.901415384615383, 8.799520261777154]
# (array([5., 5.]), array([-18.,  32.]), array([5., 5.]), 5.0)
# (array([4., 4.]), array([-17.,  30.]), array([4., 4.]), 5.0)
# (array([2., 2.]), array([-20.,  27.]), array([2., 2.]), 4.0)
# (array([1., 1.]), array([-21.,  26.]), array([1., 1.]), 2.0)
# (array([0., 0.]), array([-21.,  24.]), array([0., 0.]), 1.0)
# (array([2., 2.]), array([-24.,  34.]), array([2., 2.]), 0.0)
# (array([5., 5.]), array([-27.,  23.]), array([5., 6.]), 2.0)
# (array([5., 5.]), array([-19.,  24.]), array([5., 6.]), 5.0)
# (array([17., 17.]), array([-31.,  19.]), array([15., 19.]), 6.0)
# (array([36., 37.]), array([-23.,  32.]), array([32., 41.]), 17.0)
# (array([61., 63.]), array([-24.,  27.]), array([52., 72.]), 37.0)
# (array([ 99., 103.]), array([-24.,  27.]), array([ 83., 120.]), 59.0)
# (array([77., 80.]), array([-27.,  27.]), array([64., 93.]), 99.0)
# (array([92., 97.]), array([-23.,  26.]), array([ 76., 113.]), 77.0)
# (array([88., 93.]), array([-19.,  28.]), array([ 73., 109.]), 90.0)
# (array([85., 90.]), array([-28.,  27.]), array([ 69., 106.]), 90.0)
# (array([69., 73.]), array([-24.,  28.]), array([55., 87.]), 85.0)
# (array([65., 69.]), array([-21.,  25.]), array([52., 82.]), 81.0)
# (array([30., 32.]), array([-24.,  25.]), array([24., 38.]), 63.0)
# (array([26., 27.]), array([-22.,  17.]), array([20., 32.]), 28.0)
# (array([19., 20.]), array([-22.,  21.]), array([15., 24.]), 27.0)
# (array([16., 17.]), array([-21.,  21.]), array([12., 21.]), 19.0)
# (array([11., 12.]), array([-24.,  25.]), array([ 8., 15.]), 15.0)
# (array([11., 12.]), array([-23.,  27.]), array([ 6., 17.]), 13.0)
# (array([ 8., 10.]), array([-23.,  24.]), array([ 5., 13.]), 8.0)
# (array([0., 0.]), array([-30.,  26.]), array([7., 8.]), 6.0)
# (0.19230769230769232, 0.5769230769230769, 0.46153846153846156)

# %%
#### sim_results_pi = np.array(sim_results_pi)#### sim 
print np.mean(sim_results_pi,axis=0)

sim_results_mse = np.array(sim_results_mse)
print np.round(np.mean(sim_results_mse,axis=0)/1)
# Out:
# [0.1025641  0.58974359 0.37179487]
# [11. 32. 11.]
